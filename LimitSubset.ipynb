# %%
n,s,k=map(int,input().split())
a=list(map(int,input().split()))
def backtrack(i,cur,res):
  if res==s and len(cur)<=k:
    print("["+" ".join(map(str,cur))+"]")
    return
  if i==n or res>s or len(cur)>k: return
  backtrack(i+1,cur+[a[i]],res+a[i])
  backtrack(i+1,cur,res)
backtrack(0,[],0)
# Out:
# 5 22 2
# 10 7 5 18 12
# [10 12]

# %%
n,s=map(int,input().split())
a=list(map(int,input().split()))
f=0
def backtrack(i,cur,res):
  global f
  if res==n and len(cur)%2==0:
    print("["+" ".join(map(str,cur))+"]")
    f=1
    return
  if i==n or res>s: return
  backtrack(i+1,cur+[a[i]],res+a[i])
  backtrack(i+1,cur,res)
backtrack(0,[],0)
if not f: print(-1)
# Out:
# 5 8
# 2 3 5 1 4
# [2 3]
# [1 4]
